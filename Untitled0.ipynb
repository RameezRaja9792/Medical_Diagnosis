# %% [markdown]
# <a href="https://colab.research.google.com/github/RameezRaja9792/Medical_Diagnosis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name?")
print("Welcome", name)
# Out:
# What is your name?Rameez
# Welcome Rameez

# %%
principle = float(input("What is you principle?"))
rate = float(input("What is your rate?"))
time = float(input("What is your time?"))
simple_interest = (principle*rate*time)/100
print("Simple interest is", simple_interest)
# Out:
# What is you principle?100
# What is your rate?5
# What is your time?2
# Simple interest is 10.0

# %%
principle = float(input("What is you principle?"))
rate = float(input("What is your rate?"))
time = float(input("What is your time?"))
compound_interest = principle * (pow((1 + rate / 100), time)) - principle
print("Compound interest is", compound_interest)
# Out:
# What is you principle?100
# What is your rate?5
# What is your time?2
# Compound interest is 10.25

# %%
import math
print("1. Triangle")
print("2. Rectangle")
print("3. Circle")
choice = int(input("Enter your choice: "))
if choice == 1:
    base = float(input("Enter the base:"))
    height = float(input("Enter the height:"))
    area = (0.5*base*height)
    print("Area of triangle is", area)
if choice == 2:
    length = float(input("Enter the length: "))
    width = float(input("Enter the width: "))
    area = (length*width)
    print("Area of rectangle is", area)
if choice == 3:
    radius = float(input("Enter the radius: "))
    area = (math.pi*radius*radius)
    print("Area of circle is", area)
# Out:
# 1. Triangle
# 2. Rectangle
# 3. Circle
# Enter your choice: 3
# Enter the radius: 5
# Area of circle is 78.53981633974483
